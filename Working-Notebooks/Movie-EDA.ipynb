# %% [markdown]
# #### In this notebook we'll do basic exploration of all of the provided data sets as well as several downloaded from online. We will then determine which ones to use for further analysis. Let's start by importing all necessary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', 1000) #so we can view larger data tables
pd.set_option('display.max_columns', 1000) #so we can view larger data tables

# %matplotlib inline

# %% [markdown]
# #### Import all movie data provided by Flatiron

# %%
bom = pd.read_csv('Data/bom.movie_gross.csv.gz')
rt_info = pd.read_csv('Data/rt.movie_info.tsv.gz', delimiter='\t', encoding='iso-8859-1')
rt_reviews = pd.read_csv('Data/rt.reviews.tsv.gz', delimiter='\t', encoding='iso-8859-1')
tmdb = pd.read_csv('Data/tmdb.movies.csv.gz')
tn_budgets = pd.read_csv('Data/tn.movie_budgets.csv.gz')
imdb_fi_title = pd.read_csv('Data/imdb.fi.title.basics.csv.gz')
imdb_fi_rate = pd.read_csv('Data/imdb.fi.title.ratings.csv.gz')
imdb_fi_akas = pd.read_csv('Data/imdb.fi.title.akas.csv.gz')
imdb_fi_prin = pd.read_csv('Data/imdb.fi.title.principals.csv.gz')
imdb_fi_crew = pd.read_csv('Data/imdb.fi.title.crew.csv.gz')
imdb_fi_names = pd.read_csv('Data/imdb.fi.name.basics.csv.gz')

# %% [markdown]
# #### For each of the dataframes above we will do a `.head()` and `.info()` exploration to get a feel of what's available. I will include any thoughts for further exploration below.

# %%
display(bom.head(3))
display(bom.info())
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# None

# %% [markdown]
# ##### ^Note: Interesting that domestic_gross is a float but foreign_gross is not

# %%
display(rt_info.head(3))
display(rt_info.info())
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
#
#                          writer  theater_date      dvd_date currency  \
# 0                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# ...

# %% [markdown]
# ##### ^Note: no movie name given

# %%
display(rt_reviews.head(3))
display(rt_reviews.info())
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
# id            54432 non-null int64
# review        48869 non-null object
# rating        40915 non-null object
# fresh         54432 non-null object
# critic        51710 non-null object
# top_critic    54432 non-null int64
# publisher     54123 non-null object
# date          54432 non-null object
# ...

# %% [markdown]
# ##### ^Note: the id probably corresponds to the other rt dataframe; multiple id corresponds to multiple reviews per movie

# %%
display(tmdb.head(3))
display(tmdb.info())
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# ...

# %% [markdown]
# ##### ^Note: the specific genres aren't given; may need to find what the ids correspond to

# %%
display(tn_budgets.head(3))
display(tn_budgets.info())
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# None

# %% [markdown]
# ##### ^Note: the dollar amounts are strings

# %%
display(imdb_fi_title.head(3))
display(imdb_fi_title.info())
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
#
#    start_year  runtime_minutes              genres
# 0        2013            175.0  Action,Crime,Drama
# 1        2019            114.0     Biography,Drama
# 2        2018            122.0               Drama
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# None

# %%
display(imdb_fi_rate.head(3))
display(imdb_fi_rate.info())
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# None

# %%
display(imdb_fi_akas.head(3))
display(imdb_fi_akas.info())
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
#
#   language        types attributes  is_original_title
# 0       bg          NaN        NaN                0.0
# 1      NaN  imdbDisplay        NaN                0.0
# 2      NaN  imdbDisplay        NaN                0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
# title_id             331703 non-null object
# ordering             331703 non-null int64
# title                331703 non-null object
# region               278410 non-null object
# language             41715 non-null object
# types                168447 non-null object
# attributes           14925 non-null object
# ...

# %%
display(imdb_fi_prin.head(3))
display(imdb_fi_prin.info())
# Out:
#       tconst  ordering     nconst  category       job   characters
# 0  tt0111414         1  nm0246005     actor       NaN  ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN          NaN
# 2  tt0111414         3  nm3739909  producer  producer          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
# None

# %% [markdown]
# ##### ^Note: title and name not given - only corresponding tconst and nconst

# %%
display(imdb_fi_crew.head(3))
display(imdb_fi_crew.info())
# Out:
#       tconst  directors              writers
# 0  tt0285252  nm0899854            nm0899854
# 1  tt0438973        NaN  nm0175726,nm1802864
# 2  tt0462036  nm1940585            nm1940585
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
# tconst       146144 non-null object
# directors    140417 non-null object
# writers      110261 non-null object
# dtypes: object(3)
# memory usage: 3.3+ MB
# None

# %%
display(imdb_fi_names.head(3))
display(imdb_fi_names.info())
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
#
#                            primary_profession  \
# 0   miscellaneous,production_manager,producer
# 1  composer,music_department,sound_department
# 2                  miscellaneous,actor,writer
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
# nconst                606648 non-null object
# primary_name          606648 non-null object
# birth_year            82736 non-null float64
# death_year            6783 non-null float64
# primary_profession    555308 non-null object
# ...

# %% [markdown]
# ##### ^Note: This must be where we can obtain names to correspond with nconst

# %% [markdown]
# #### We will also create dataframes from the latest iMDb files to determine which will serve our purposes better. These files are significantly larger.

# %%
imdb_title = pd.read_csv('Data/imdb.title.basics.tsv.gz', sep='\t', na_values="\\N")
# Out:
# /Users/shawn/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ##### ^Note: it seems that some of the columns have mixed data types. Same applies to warnings below.

# %%
imdb_rate = pd.read_csv('Data/imdb.title.ratings.tsv.gz', sep='\t', na_values="\\N")

# %%
imdb_akas = pd.read_csv('Data/imdb.title.akas.tsv.gz', sep='\t', na_values="\\N")
# Out:
# /Users/shawn/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
imdb_prin = pd.read_csv('Data/imdb.title.principals.tsv.gz', sep='\t', na_values="\\N")
# Out:
# /Users/shawn/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
imdb_crew = pd.read_csv('Data/imdb.title.crew.tsv.gz', sep='\t', na_values="\\N")

# %%
imdb_name = pd.read_csv('Data/imdb.name.basics.tsv.gz', sep='\t', na_values="\\N")

# %%
display(imdb_title.head(3))
display(imdb_title.info())
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
#
#    isAdult  startYear  endYear runtimeMinutes                    genres
# 0        0     1894.0      NaN              1         Documentary,Short
# 1        0     1892.0      NaN              5           Animation,Short
# 2        0     1892.0      NaN              4  Animation,Comedy,Romance
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7322814 entries, 0 to 7322813
# Data columns (total 9 columns):
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           int64
# startYear         float64
# endYear           float64
# runtimeMinutes    object
# genres            object
# dtypes: float64(2), int64(1), object(6)
# ...

# %%
display(imdb_rate.head(3))
display(imdb_rate.info())
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1658
# 1  tt0000002            6.1       201
# 2  tt0000003            6.5      1371
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1088497 entries, 0 to 1088496
# Data columns (total 3 columns):
# tconst           1088497 non-null object
# averageRating    1088497 non-null float64
# numVotes         1088497 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 24.9+ MB
# None

# %%
display(imdb_akas.head(3))
display(imdb_akas.info())
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay            NaN              0.0
# 1          NaN  literal title              0.0
# 2  imdbDisplay            NaN              0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24089312 entries, 0 to 24089311
# Data columns (total 8 columns):
# titleId            object
# ordering           int64
# title              object
# region             object
# language           object
# types              object
# attributes         object
# isOriginalTitle    float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.4+ GB
# None

# %%
display(imdb_prin.head(3))
display(imdb_prin.info())
# Out:
#       tconst  ordering     nconst  category       job   characters
# 0  tt0111414         1  nm0246005     actor       NaN  ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN          NaN
# 2  tt0111414         3  nm3739909  producer  producer          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
# None

# %%
display(imdb_crew.head(3))
display(imdb_crew.info())
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690     NaN
# 1  tt0000002  nm0721526     NaN
# 2  tt0000003  nm0721526     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7325472 entries, 0 to 7325471
# Data columns (total 3 columns):
# tconst       object
# directors    object
# writers      object
# dtypes: object(3)
# memory usage: 167.7+ MB
# None

# %%
display(imdb_name.head(3))
display(imdb_name.info())
# Out:
#       nconst      primaryName  birthYear  deathYear  \
# 0  nm0000001     Fred Astaire     1899.0     1987.0
# 1  nm0000002    Lauren Bacall     1924.0     2014.0
# 2  nm0000003  Brigitte Bardot     1934.0        NaN
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
#
#                             knownForTitles
# 0  tt0031983,tt0072308,tt0050419,tt0053137
# 1  tt0071877,tt0117057,tt0037382,tt0038355
# 2  tt0049189,tt0054452,tt0059956,tt0057345
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10488852 entries, 0 to 10488851
# Data columns (total 6 columns):
# nconst               object
# primaryName          object
# birthYear            float64
# deathYear            float64
# primaryProfession    object
# knownForTitles       object
# dtypes: float64(2), object(4)
# memory usage: 480.1+ MB
# None

# %% [markdown]
# #### Below are further exploratory measures I used towards deciding which dataframes I wanted to use for my final analysis

# %%
imdb_main = imdb_title[imdb_title['isAdult'] == 0] #remove adult films

# %%
imdb_main = imdb_main[imdb_main['startYear'].between(2000, 2020)] #restrict to last 20 years

# %%
imdb_main = imdb_main[imdb_main['titleType'] == 'movie'] #remove other types other than movies

# %%
imdb_main.shape #see what's left
# Out:
# (238759, 9)

# %%
imdb_main[imdb_main['primaryTitle'].str.match('Star Trek Beyond')] #test if it's possible to find a specific title
# Out:
#             tconst titleType      primaryTitle     originalTitle  isAdult  \
# 4028760  tt2660888     movie  Star Trek Beyond  Star Trek Beyond        0
#
#          startYear  endYear runtimeMinutes                   genres
# 4028760     2016.0      NaN            122  Action,Adventure,Sci-Fi

# %%
bom['year'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
imdb_akas['language'].unique()
# Out:
# array(['bg', nan, 'he', 'fr', 'tr', 'ka', 'ta', 'te', 'en', 'sv', 'hr',
#        'de', 'hi', 'sl', 'ca', 'fa', 'es', 'ml', 'cmn', 'yue', 'qbp',
#        'cs', 'ar', 'ms', 'nl', 'qbn', 'tl', 'mr', 'id', 'ga', 'th', 'bs',
#        'bn', 'sr', 'sk', 'et', 'it', 'hu', 'da', 'el', 'pt', 'fi', 'no',
#        'ru', 'uk', 'ro', 'lt', 'ur', 'gsw', 'mi', 'az', 'eu', 'la', 'gl',
#        'af', 'kn', 'pl', 'yi', 'wo', 'zu', 'xh', 'st', 'tn', 'iu', 'vi',
#        'cy', 'ko', 'fro', 'gu', 'mk', 'ps', 'pa', 'zh', 'ja', 'gd', 'ku',
#        'qal'], dtype=object)

# %%
imdb_akas.groupby(by=['language']).count()
# Out:
#           title_id  ordering  title  region  types  attributes  \
# language
# af              15        15     15      15      8           7
# ar              98        98     98      98     74          24
# az               2         2      2       2      2           0
# bg            3609      3609   3609    3609     19           9
# bn              61        61     61      61     46          13
# bs              97        97     97      97     96           1
# ca             239       239    239     239    218          16
# cmn            727       727    727     727    484         219
# cs               5         5      5       5      4           0
# cy               1         1      1       1      1           0
# da               3         3      3       3      3           0
# de             131       131    131     131    110          18
# el              14        14     14      14      1           1
# en           22895     22895  22895   22895  17937        3597
# ...

# %%
len(imdb_title.titleType == 'videoGame')
# Out:
# 7322814

# %%
group_by_titleType = imdb_title.groupby(by=['titleType'])
type_avg = group_by_titleType.mean()
type_count = group_by_titleType.count()

# %%
group_by_titleType

# %%
print(group_by_titleType)

# %%
type_avg
# Out:
#                isAdult    startYear      endYear
# titleType
# movie         0.015936  1988.238101          NaN
# short         0.001731  1994.011673          NaN
# tvEpisode     0.026651  2005.222745          NaN
# tvMiniSeries  0.004363  2007.652101  2009.131994
# tvMovie       0.000773  1995.146646          NaN
# tvSeries      0.006620  2004.493852  2001.758498
# tvShort       0.000267  1996.573330          NaN
# tvSpecial     0.000397  2003.543335          NaN
# video         0.307568  2007.636321          NaN
# videoGame     0.005210  2003.197678          NaN

# %%
type_count
# Out:
#                tconst  primaryTitle  originalTitle  isAdult  startYear  \
# titleType
# movie          558225        558225         558225   558225     491509
# short          776798        776798         776798   776798     758013
# tvEpisode     5278128       5278119        5278119  5278128    4712387
# tvMiniSeries    34152         34152          34152    34152      32314
# tvMovie        111205        111205         111205   111205     108172
# tvSeries       195634        195634         195634   195634     183474
# tvShort         26205         26205          26205    26205      25999
# tvSpecial       30230         30230          30230    30230      30103
# video          285560        285560         285560   285560     284339
# videoGame       26677         26677          26677    26677      26265
#
#               endYear  runtimeMinutes   genres
# titleType
# movie               0          352090   488248
# short               0          507639   776626
# ...

# %%
imdb_title[imdb_title.titleType == 'movie']
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 331      tt0000335     movie
# 498      tt0000502     movie
# 570      tt0000574     movie
# 610      tt0000615     movie
# ...            ...       ...
# 7322703  tt9916622     movie
# 7322730  tt9916680     movie
# 7322742  tt9916706     movie
# 7322753  tt9916730     movie
# 7322764  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 331                                  Soldiers of the Cross
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 610                                     Robbery Under Arms
# ...                                                    ...
# 7322703        Rodolpho Teóphilo - O Legado de um Pioneiro
# 7322730  De la ilusión al desconcierto: cine colombiano...
# 7322742                                    Dankyavar Danka
# ...

# %%
len(imdb_title.genres.unique())
# Out:
# 2264

# %%
imdb_dl_akas.iloc[500000]
# Out:
# titleId                    tt0072890
# ordering                          19
# title              Dog Day Afternoon
# region                            US
# language                         NaN
# types                    imdbDisplay
# attributes                       NaN
# isOriginalTitle                    0
# Name: 500000, dtype: object

# %%
bom.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
bom.year.unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
tn_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
tn_budgets.release_date.unique()
# Out:
# array(['Dec 18, 2009', 'May 20, 2011', 'Jun 7, 2019', ..., 'Aug 14, 2008',
#        'Feb 26, 1993', 'Jul 13, 2005'], dtype=object)

# %%
tn_budgets['release_date'] = pd.to_datetime(tn_budgets['release_date'], infer_datetime_format=True)

# %%
tn_budgets['worldwide_gross'] = tn_budgets['worldwide_gross'].str.replace('$', '')
tn_budgets['worldwide_gross'] = tn_budgets['worldwide_gross'].str.replace(',', '')

# %%
tn_budgets['worldwide_gross'] = tn_budgets['worldwide_gross'].astype(int)

# %%
tn_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null datetime64[ns]
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 271.2+ KB

# %%
tn_budgets.sort_values(by = ['worldwide_gross'], ascending=False).head(100)
# Out:
#        id release_date                                              movie  \
# 0       1   2009-12-18                                             Avatar
# 42     43   1997-12-19                                            Titanic
# 5       6   2015-12-18               Star Wars Ep. VII: The Force Awakens
# 6       7   2018-04-27                             Avengers: Infinity War
# 33     34   2015-06-12                                     Jurassic World
# 66     67   2015-04-03                                          Furious 7
# 26     27   2012-05-04                                       The Avengers
# 3       4   2015-05-01                            Avengers: Age of Ultron
# 41     42   2018-02-16                                      Black Panther
# 260    61   2011-07-15      Harry Potter and the Deathly Hallows: Part II
# 4       5   2017-12-15                  Star Wars Ep. VIII: The Last Jedi
# 112    13   2018-06-22                     Jurassic World: Fallen Kingdom
# ...
